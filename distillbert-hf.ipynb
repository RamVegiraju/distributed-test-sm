# %%
from sagemaker.huggingface import HuggingFaceModel
import sagemaker

role = sagemaker.get_execution_role()

# %%
# Hub Model configuration. https://huggingface.co/models
hub = {
    'HF_MODEL_ID':'distilbert-base-uncased',
    'HF_TASK':'text-classification'
}

# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
    transformers_version='4.17.0',
    pytorch_version='1.10.2',
    py_version='py38',
    env=hub,
    role=role, 
)

# %%
# deploy model to SageMaker Inference
predictor = huggingface_model.deploy(
    initial_instance_count=1, # number of instances
    instance_type='ml.c5.xlarge' # ec2 instance type
)
# Out:
# -----!

# %%
predictor.predict({
    'inputs': "I am super happy right now."
})
# Out:
# [{'label': 'LABEL_0', 'score': 0.5521041750907898}]

# %%
import boto3
import json
client = boto3.client('sagemaker-runtime')
content_type = "application/json"
request_body = {'inputs': "I am super happy right now."}
data = json.loads(json.dumps(request_body))
payload = json.dumps(data)
response = client.invoke_endpoint(
    EndpointName=predictor.endpoint_name,
    ContentType=content_type,
    Body=payload)
result = response['Body'].read()
result
# Out:
# b'[{"label":"LABEL_0","score":0.5521041750907898}]'

# %%
request_body = {'inputs': "I am super happy right now."}
data = json.loads(json.dumps(request_body))
payload = json.dumps(data)
payload
# Out:
# '{"inputs": "I am super happy right now."}'

# %%
#!pip install locust

# %%
# !which locust
# Out:
# /home/ec2-user/anaconda3/envs/python3/bin/locust

# %%
import boto3
from botocore.config import Config
import pandas as pd
import itertools
import datetime

region = 'us-east-1'
content_type = 'application/json'
endpoint_name='huggingface-pytorch-inference-2022-07-25-17-21-31-881'

boto3config = Config(
    retries={
        'max_attempts': 100,
        'mode': 'standard'
    }
)

payload='{"inputs": "I am super happy right now."}'

sagemaker_client = boto3.client('sagemaker-runtime',
                                     config=boto3config,
                                     region_name=region)

response = sagemaker_client.invoke_endpoint(
    EndpointName=endpoint_name,
    Body=payload,
    ContentType=content_type
)
response_body = response["Body"].read()

response_body
# Out:
# b'[{"label":"LABEL_1","score":0.5474691987037659}]'

# %%
cw_start = datetime.datetime.utcnow()
# !/home/ec2-user/anaconda3/envs/python3/bin/locust -f locust_script.py -u 10 --headless --host=http://huggingface-pytorch-inference-2022-07-25-17-21-31-881 --stop-timeout 90 -L DEBUG -t 5m --logfile=logfile.log --csv=locust.csv --csv-full-history --reset-stats              
cw_end = datetime.datetime.utcnow()
# Out:
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#  Aggregated       0     0(0.00%)  |       0       0       0       0  |    0.00    0.00
#
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint      41     0(0.00%)  |      68      56     127      63  |    0.00    0.00
# --------------------------------------------------------------------------------
#  Aggregated      41     0(0.00%)  |      68      56     127      63  |    0.00    0.00
#
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint     110     0(0.00%)  |      88      56     213      86  |   19.50    0.00
# --------------------------------------------------------------------------------
#  Aggregated     110     0(0.00%)  |      88      56     213      86  |   19.50    0.00
#
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint     187     0(0.00%)  |     108      56     277     100  |   26.75    0.00
# --------------------------------------------------------------------------------
#  Aggregated     187     0(0.00%)  |     108      56     277     100  |   26.75    0.00
#
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
# huggingface-pytorch-inference-2022-07-25-17-21-31-881
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint
0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   11777     0(0.00%)  |     226     158    1793     220  |   45.30    0.00
# --------------------------------------------------------------------------------
#  Aggregated   11777     0(0.00%)  |     226     158    1793     220  |   45.30    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   11869     0(0.00%)  |     226     158    1793     220  |   45.40    0.00
# --------------------------------------------------------------------------------
#  Aggregated   11869     0(0.00%)  |     226     158    1793     220  |   45.40    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   11960     0(0.00%)  |     226     158    1793     220  |   45.40    0.00
# --------------------------------------------------------------------------------
#  Aggregated   11960     0(0.00%)  |     226     158    1793     220  |   45.40    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12051     0(0.00%)  |     226     158    1793     220  |   45.60    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12051     0(0.00%)  |     226     158    1793     220  |   45.60    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12142     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12142     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12234     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12234     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12324     0(0.00%)  |     225     158    1793     220  |   45.70    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12324     0(0.00%)  |     225     158    1793     220  |   45.70    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12416     0(0.00%)  |     225     158    1793     220  |   45.80    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12416     0(0.00%)  |     225     158    1793     220  |   45.80    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12507     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12507     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12598     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12598     0(0.00%)  |     225     158    1793     220  |   45.60    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12689     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12689     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12781     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12781     0(0.00%)  |     225     158    1793     220  |   45.50    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12872     0(0.00%)  |     225     158    1793     220  |   45.40    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12872     0(0.00%)  |     225     158    1793     220  |   45.40    0.00
#
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint   12874     0(0.00%)  |     225     158    1793     220  |   44.22    0.00
# --------------------------------------------------------------------------------
#  Aggregated   12874     0(0.00%)  |     225     158    1793     220  |   44.22    0.00
#
# Response time percentiles (approximated)
#  Type     Name      50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  custom_protocol_boto3 sagemaker_client_invoke_endpoint      220    230    240    240    250    260    300    330    470   1200   1800  12874
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  None     Aggregated      220    230    240    240    250    260    300    330    470   1200   1800  12874

# %%
locust_data = pd.read_csv('locust.csv_stats.csv')
for index, row in locust_data.head(n=2).iterrows():
     print(index, row)
# Out:
# 0 Type                                custom_protocol_boto3
# Name                     sagemaker_client_invoke_endpoint
# Request Count                                       12836
# Failure Count                                           0
# Median Response Time                                  220
# Average Response Time                             225.559
# Min Response Time                                     158
# Max Response Time                                    1793
# Average Content Size                                   48
# Requests/s                                        44.2107
# Failures/s                                              0
# 50%                                                   220
# 66%                                                   230
# 75%                                                   240
# 80%                                                   240
# 90%                                                   250
# 95%                                                   260
# 98%                                                   300
# 99%                                                   330
# 99.9%                                                 470
# 99.99%                                               1200
# 100%                                                 1800
# Name: 0, dtype: object
# 1 Type                            NaN
# Name                     Aggregated
# Request Count                 12836
# Failure Count                     0
# Median Response Time            220
# Average Response Time       225.559
# Min Response Time               158
# Max Response Time              1793
# Average Content Size             48
# Requests/s                  44.2107
# Failures/s                        0
# 50%                             220
# 66%                             230
# 75%                             240
# 80%                             240
# 90%                             250
# 95%                             260
# 98%                             300
# 99%                             330
# 99.9%                           470
# 99.99%                         1200
# 100%                           1800
# Name: 1, dtype: object
